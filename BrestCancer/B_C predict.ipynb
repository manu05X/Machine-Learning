# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('BreastCancer_Prognostic_v12.csv')

# %%
df.head()
# Out:
#          ID Outcome   Time  radius_mean  texture_mean  perimeter_mean  \
# 0  119513.0       N   31.0        18.02         27.60          117.50
# 1    8423.0       N   61.0        17.99         10.38          122.80
# 2  842517.0       N  116.0        21.37         17.44          137.50
# 3  843483.0       N  123.0        11.42         20.38           77.58
# 4  843584.0       R   27.0        20.29         14.34          135.10
#
#    area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0     1013.0          0.09489            0.1036          0.1086
# 1     1001.0          0.11840            0.2776          0.3001
# 2     1373.0          0.08836            0.1189          0.1255
# 3      386.1          0.14250            0.2839          0.2414
# 4     1297.0          0.10030            0.1328          0.1980
#
#          ...          Worst_perimeter  Worst_area  Worst_smoothness  \
# 0        ...                   139.70      1436.0            0.1195
# 1        ...                   184.60      2019.0            0.1622
# 2        ...                   159.10      1949.0            0.1188
# 3        ...                    98.87       567.7            0.2098
# 4        ...                   152.20      1575.0            0.1374
#
#    Worst_compactness  Worst_concavity  Worst_concave_points  Worst_symmetry  \
# 0             0.1926           0.3140                0.1170          0.2677
# 1             0.6656           0.7119                0.2654          0.4601
# 2             0.3449           0.3414                0.2032          0.4334
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    Worst_fractal_dimension  Tumor_Size  Lymph_Node_Status
# 0                  0.08113         5.0                  5
# 1                  0.11890         3.0                  2
# 2                  0.09067         2.5                  0
# 3                  0.17300         2.0                  0
# 4                  0.07678         3.5                  0
#
# [5 rows x 35 columns]

# %%
df.tail()
# Out:
#            ID Outcome  Time  radius_mean  texture_mean  perimeter_mean  \
# 193  942640.0       N  10.0        22.52         21.92           146.9
# 194  943471.0       N   8.0        15.44         31.18           101.0
# 195   94547.0       N  12.0        17.17         29.19           110.0
# 196  947204.0       R   3.0        21.42         22.84           145.0
# 197  947489.0       N   6.0        16.70         28.13           110.3
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 193     1597.0          0.07592           0.09162         0.06862
# 194      740.4          0.09399           0.10620         0.13750
# 195      915.3          0.08952           0.06655         0.06583
# 196     1440.0          0.10700           0.19390         0.23800
# 197      885.4          0.08896           0.11310         0.10120
#
#            ...          Worst_perimeter  Worst_area  Worst_smoothness  \
# 193        ...                    162.1      1902.0           0.08191
# 194        ...                    112.6       929.0           0.12720
# 195        ...                    132.5      1295.0           0.12610
# 196        ...                    198.3      2375.0           0.14980
# 197        ...                    128.8      1213.0           0.13300
#
#      Worst_compactness  Worst_concavity  Worst_concave_points  Worst_symmetry  \
# 193             0.1319           0.1056               0.09378          0.2061
# 194             0.2362           0.2975               0.12860          0.2914
# 195             0.1572           0.2141               0.09520          0.3362
# 196             0.4379           0.5411               0.22150          0.2832
# 197             0.2808           0.3455               0.13170          0.3035
#
#      Worst_fractal_dimension  Tumor_Size  Lymph_Node_Status
# 193                  0.05788         6.0                  2
# 194                  0.08024         1.5                  0
# 195                  0.06033         3.7                  0
# 196                  0.08981         3.0                  ?
# 197                  0.08036         3.5                  0
#
# [5 rows x 35 columns]

# %%
df.shape
# Out:
# (198, 35)

# %%
df.describe().T
# Out:
#                            count          mean           std          min  \
# ID                         198.0  1.990469e+06  2.889025e+06  8423.000000
# Time                       198.0  4.673232e+01  3.446287e+01     1.000000
# radius_mean                198.0  1.741232e+01  3.161676e+00    10.950000
# texture_mean               198.0  2.227601e+01  4.298290e+00    10.380000
# perimeter_mean             198.0  1.148566e+02  2.138340e+01    71.900000
# area_mean                  198.0  9.700409e+02  3.521492e+02   361.600000
# smoothness_mean            198.0  1.026814e-01  1.252243e-02     0.074970
# compactness_mean           198.0  1.426478e-01  4.989760e-02     0.046050
# concavity_mean             198.0  1.562428e-01  7.057226e-02     0.023980
# concave_points_mean        198.0  8.677561e-02  3.387663e-02     0.020310
# symmetry_mean              198.0  1.927540e-01  2.743689e-02     0.130800
# fractal_dimension_mean     198.0  6.270551e-02  7.239530e-03     0.050250
# radius_std_dev             198.0  6.033465e-01  3.101122e-01     0.193800
# texture_std_dev            198.0  1.264450e+00  5.264669e-01     0.362100
# perimeter_std_dev          198.0  4.255394e+00  2.194128e+00     1.153000
# area_std_dev               198.0  7.022874e+01  4.798225e+01    13.990000
# smoothness_std_dev         198.0  6.761864e-03  2.974270e-03     0.002667
# compactness_std_dev        198.0  3.119929e-02  1.761293e-02     0.007347
# concavity_std_dev          198.0  4.074980e-02  2.086872e-02     0.010940
# concave_points_std_dev     198.0  1.509925e-02  5.504267e-03     0.005174
# symmetry_std_dev           198.0  2.055486e-02  9.578243e-03     0.007882
# fractal_dimension_std_dev  198.0  3.986904e-03  1.937845e-03     0.001087
# Worst_radius               198.0  2.102182e+01  4.242997e+00    12.840000
# Worst_texture              198.0  3.013909e+01  6.017777e+00    16.670000
# Worst_perimeter            198.0  1.403478e+02  2.889228e+01    85.100000
# Worst_area                 198.0  1.404959e+03  5.860070e+02   508.100000
# Worst_smoothness           198.0  1.439208e-01  2.200396e-02     0.081910
# Worst_compactness          198.0  3.651018e-01  1.639650e-01     0.051310
# Worst_concavity            198.0  4.366853e-01  1.736245e-01     0.023980
# Worst_concave_points       198.0  1.787775e-01  4.518052e-02     0.028990
# Worst_symmetry             198.0  3.234040e-01  7.516089e-02     0.156500
# Worst_fractal_dimension    198.0  9.082813e-02  2.117197e-02     0.055040
# Tumor_Size                 198.0  2.847475e+00  1.937964e+00     0.400000
#
#                                      25%            50%            75%  \
# ID                         855745.250000  886339.000000  927995.750000
# Time                           14.000000      39.500000      72.750000
# radius_mean                    15.052500      17.290000      19.580000
# texture_mean                   19.412500      21.750000      24.655000
# perimeter_mean                 98.160000     113.700000     129.650000
# area_mean                     702.525000     929.100000    1193.500000
# smoothness_mean                 0.093900       0.101900       0.110975
# compactness_mean                0.110200       0.131750       0.172200
# concavity_mean                  0.106850       0.151350       0.200500
# concave_points_mean             0.063670       0.086075       0.103925
# symmetry_mean                   0.174075       0.189350       0.209325
# fractal_dimension_mean          0.056718       0.061715       0.066715
# radius_std_dev                  0.388200       0.533250       0.750900
# texture_std_dev                 0.921300       1.168500       1.463250
# perimeter_std_dev               2.742500       3.767000       5.212750
# area_std_dev                   35.365000      58.455000      92.477500
# smoothness_std_dev              0.005001       0.006193       0.007973
# compactness_std_dev             0.019803       0.027880       0.038335
# concavity_std_dev               0.026810       0.036910       0.048970
# concave_points_std_dev          0.011422       0.014175       0.017665
# symmetry_std_dev                0.014795       0.017905       0.022880
# fractal_dimension_std_dev       0.002748       0.003719       0.004630
# Worst_radius                   17.632500      20.525000      23.730000
# Worst_texture                  26.210000      30.135000      33.555000
# Worst_perimeter               118.075000     136.500000     159.875000
# Worst_area                    947.275000    1295.000000    1694.250000
# Worst_smoothness                0.129325       0.141850       0.154875
# Worst_compactness               0.248700       0.351300       0.423675
# Worst_concavity                 0.322150       0.402350       0.541050
# Worst_concave_points            0.152650       0.179250       0.207125
# Worst_symmetry                  0.275950       0.310300       0.358800
# Worst_fractal_dimension         0.076578       0.086890       0.101375
# Tumor_Size                      1.500000       2.500000       3.500000
#
#                                     max
# ID                         9.411300e+06
# Time                       1.250000e+02
# radius_mean                2.722000e+01
# texture_mean               3.928000e+01
# perimeter_mean             1.821000e+02
# area_mean                  2.250000e+03
# smoothness_mean            1.447000e-01
# compactness_mean           3.114000e-01
# concavity_mean             4.268000e-01
# concave_points_mean        2.012000e-01
# symmetry_mean              3.040000e-01
# fractal_dimension_mean     9.744000e-02
# radius_std_dev             1.819000e+00
# texture_std_dev            3.503000e+00
# perimeter_std_dev          1.328000e+01
# area_std_dev               3.160000e+02
# smoothness_std_dev         3.113000e-02
# compactness_std_dev        1.354000e-01
# concavity_std_dev          1.438000e-01
# concave_points_std_dev     3.927000e-02
# symmetry_std_dev           6.041000e-02
# fractal_dimension_std_dev  1.256000e-02
# Worst_radius               3.513000e+01
# Worst_texture              4.954000e+01
# Worst_perimeter            2.322000e+02
# Worst_area                 3.903000e+03
# Worst_smoothness           2.226000e-01
# Worst_compactness          1.058000e+00
# Worst_concavity            1.170000e+00
# Worst_concave_points       2.903000e-01
# Worst_symmetry             6.638000e-01
# Worst_fractal_dimension    2.075000e-01
# Tumor_Size                 1.000000e+01

# %%
df.Outcome.unique()
# Out:
# array(['N', 'R'], dtype=object)

# %%
df['Outcome'].value_counts()
# Out:
# N    151
# R     47
# Name: Outcome, dtype: int64

# %%
sns.countplot(df['Outcome'], palette='husl')

# %% [markdown]
# ## clean and prepare the data

# %%
df.drop('ID',axis=1,inplace=True)

# %%
df.head()
# Out:
#   Outcome   Time  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0       N   31.0        18.02         27.60          117.50     1013.0
# 1       N   61.0        17.99         10.38          122.80     1001.0
# 2       N  116.0        21.37         17.44          137.50     1373.0
# 3       N  123.0        11.42         20.38           77.58      386.1
# 4       R   27.0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.09489            0.1036          0.1086              0.07055
# 1          0.11840            0.2776          0.3001              0.14710
# 2          0.08836            0.1189          0.1255              0.08180
# 3          0.14250            0.2839          0.2414              0.10520
# 4          0.10030            0.1328          0.1980              0.10430
#
#          ...          Worst_perimeter  Worst_area  Worst_smoothness  \
# 0        ...                   139.70      1436.0            0.1195
# 1        ...                   184.60      2019.0            0.1622
# 2        ...                   159.10      1949.0            0.1188
# 3        ...                    98.87       567.7            0.2098
# 4        ...                   152.20      1575.0            0.1374
#
#    Worst_compactness  Worst_concavity  Worst_concave_points  Worst_symmetry  \
# 0             0.1926           0.3140                0.1170          0.2677
# 1             0.6656           0.7119                0.2654          0.4601
# 2             0.3449           0.3414                0.2032          0.4334
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    Worst_fractal_dimension  Tumor_Size  Lymph_Node_Status
# 0                  0.08113         5.0                  5
# 1                  0.11890         3.0                  2
# 2                  0.09067         2.5                  0
# 3                  0.17300         2.0                  0
# 4                  0.07678         3.5                  0
#
# [5 rows x 34 columns]

# %%
df['Outcome'] = df['Outcome'].map({'N':1,'R':0})
df.head()
# Out:
#    Outcome   Time  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0        1   31.0        18.02         27.60          117.50     1013.0
# 1        1   61.0        17.99         10.38          122.80     1001.0
# 2        1  116.0        21.37         17.44          137.50     1373.0
# 3        1  123.0        11.42         20.38           77.58      386.1
# 4        0   27.0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.09489            0.1036          0.1086              0.07055
# 1          0.11840            0.2776          0.3001              0.14710
# 2          0.08836            0.1189          0.1255              0.08180
# 3          0.14250            0.2839          0.2414              0.10520
# 4          0.10030            0.1328          0.1980              0.10430
#
#          ...          Worst_perimeter  Worst_area  Worst_smoothness  \
# 0        ...                   139.70      1436.0            0.1195
# 1        ...                   184.60      2019.0            0.1622
# 2        ...                   159.10      1949.0            0.1188
# 3        ...                    98.87       567.7            0.2098
# 4        ...                   152.20      1575.0            0.1374
#
#    Worst_compactness  Worst_concavity  Worst_concave_points  Worst_symmetry  \
# 0             0.1926           0.3140                0.1170          0.2677
# 1             0.6656           0.7119                0.2654          0.4601
# 2             0.3449           0.3414                0.2032          0.4334
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    Worst_fractal_dimension  Tumor_Size  Lymph_Node_Status
# 0                  0.08113         5.0                  5
# 1                  0.11890         3.0                  2
# 2                  0.09067         2.5                  0
# 3                  0.17300         2.0                  0
# 4                  0.07678         3.5                  0
#
# [5 rows x 34 columns]

# %%
df.isnull().sum()
# Out:
# Outcome                      0
# Time                         0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave_points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_std_dev               0
# texture_std_dev              0
# perimeter_std_dev            0
# area_std_dev                 0
# smoothness_std_dev           0
# compactness_std_dev          0
# concavity_std_dev            0
# concave_points_std_dev       0
# symmetry_std_dev             0
# fractal_dimension_std_dev    0
# Worst_radius                 0
# Worst_texture                0
# Worst_perimeter              0
# Worst_area                   0
# Worst_smoothness             0
# Worst_compactness            0
# Worst_concavity              0
# Worst_concave_points         0
# Worst_symmetry               0
# Worst_fractal_dimension      0
# Tumor_Size                   0
# Lymph_Node_Status            0
# dtype: int64

# %%
#determine the corelation between each feature
df.corr()
# Out:
#                             Outcome      Time  radius_mean  texture_mean  \
# Outcome                    1.000000  0.351326    -0.174124      0.064295
# Time                       0.351326  1.000000    -0.344722     -0.264671
# radius_mean               -0.174124 -0.344722     1.000000      0.143456
# texture_mean               0.064295 -0.264671     0.143456      1.000000
# perimeter_mean            -0.176486 -0.346080     0.995933      0.142033
# area_mean                 -0.189893 -0.344031     0.992855      0.140440
# smoothness_mean           -0.020778  0.164793    -0.158239     -0.192262
# compactness_mean          -0.000798  0.010000     0.159017     -0.039803
# concavity_mean            -0.054893 -0.139475     0.469518      0.037165
# concave_points_mean       -0.118224 -0.171841     0.664010      0.006687
# symmetry_mean              0.099777  0.177311    -0.051610     -0.165166
# fractal_dimension_mean     0.112352  0.269992    -0.416674     -0.145572
# radius_std_dev            -0.132512 -0.214543     0.602035      0.059168
# texture_std_dev            0.076212 -0.230477     0.079693      0.382533
# perimeter_std_dev         -0.141633 -0.231621     0.588927      0.075025
# area_std_dev              -0.151826 -0.244159     0.710586      0.068517
# smoothness_std_dev         0.052213  0.019775    -0.036419      0.027119
# compactness_std_dev        0.009537 -0.002386     0.023647      0.063988
# concavity_std_dev          0.060379 -0.108648     0.154254      0.071920
# concave_points_std_dev     0.065570 -0.140754     0.224771      0.010470
# symmetry_std_dev           0.044325  0.011156     0.019146     -0.094843
# fractal_dimension_std_dev  0.042751  0.099203    -0.072618     -0.020673
# Worst_radius              -0.233225 -0.265115     0.924183      0.123028
# Worst_texture              0.051134 -0.171125    -0.039439      0.862050
# Worst_perimeter           -0.231998 -0.280596     0.915053      0.123674
# Worst_area                -0.235310 -0.253930     0.891489      0.117467
# Worst_smoothness          -0.038520  0.212769    -0.372894     -0.113308
# Worst_compactness          0.020067  0.120516    -0.150712     -0.006467
# Worst_concavity           -0.017621  0.009546     0.038952      0.013635
# Worst_concave_points      -0.074345 -0.026541     0.357869     -0.069921
# Worst_symmetry             0.074731  0.247678    -0.232142     -0.186850
# Worst_fractal_dimension    0.055170  0.288715    -0.414340     -0.085847
# Tumor_Size                -0.177273 -0.133355     0.172102      0.027073
#
#                            perimeter_mean  area_mean  smoothness_mean  \
# Outcome                         -0.176486  -0.189893        -0.020778
# Time                            -0.346080  -0.344031         0.164793
# radius_mean                      0.995933   0.992855        -0.158239
# texture_mean                     0.142033   0.140440        -0.192262
# perimeter_mean                   1.000000   0.990699        -0.102912
# area_mean                        0.990699   1.000000        -0.141470
# smoothness_mean                 -0.102912  -0.141470         1.000000
# compactness_mean                 0.236721   0.163176         0.666559
# concavity_mean                   0.533194   0.475862         0.623867
# concave_points_mean              0.712766   0.667530         0.545734
# symmetry_mean                   -0.006512  -0.060785         0.540761
# fractal_dimension_mean          -0.353560  -0.397733         0.744890
# radius_std_dev                   0.612708   0.623019         0.094728
# texture_std_dev                  0.092256   0.084288         0.153848
# perimeter_std_dev                0.609964   0.609887         0.099518
# area_std_dev                     0.718581   0.740830         0.037955
# smoothness_std_dev              -0.011788  -0.032969         0.344678
# compactness_std_dev              0.080725   0.020395         0.372393
# concavity_std_dev                0.202027   0.144443         0.375011
# concave_points_std_dev           0.254473   0.213582         0.223510
# symmetry_std_dev                 0.038613   0.009121         0.223723
# fractal_dimension_std_dev       -0.019514  -0.071906         0.486112
# Worst_radius                     0.921552   0.932381        -0.115092
# Worst_texture                   -0.039728  -0.032122        -0.106172
# Worst_perimeter                  0.923659   0.925335        -0.064664
# Worst_area                       0.889344   0.914166        -0.106691
# Worst_smoothness                -0.331667  -0.345111         0.745400
# Worst_compactness               -0.092041  -0.141358         0.447849
# Worst_concavity                  0.096790   0.046641         0.499438
# Worst_concave_points             0.410000   0.365026         0.531015
# Worst_symmetry                  -0.206949  -0.234294         0.308964
# Worst_fractal_dimension         -0.364022  -0.395026         0.535751
# Tumor_Size                       0.166489   0.174491        -0.084376
#
#                            compactness_mean  concavity_mean  \
# Outcome                           -0.000798       -0.054893
# Time                               0.010000       -0.139475
# radius_mean                        0.159017        0.469518
# texture_mean                      -0.039803        0.037165
# perimeter_mean                     0.236721        0.533194
# area_mean                          0.163176        0.475862
# smoothness_mean                    0.666559        0.623867
# compactness_mean                   1.000000        0.836015
# concavity_mean                     0.836015        1.000000
# concave_points_mean                0.716438        0.909990
# symmetry_mean                      0.666822        0.524861
# fractal_dimension_mean             0.735474        0.449928
# radius_std_dev                     0.251568        0.427031
# texture_std_dev                    0.082994        0.181984
# perimeter_std_dev                  0.318684        0.468426
# area_std_dev                       0.233326        0.449059
# smoothness_std_dev                 0.212552        0.297014
# compactness_std_dev                0.714122        0.564196
# concavity_std_dev                  0.599020        0.676804
# concave_points_std_dev             0.384747        0.434928
# symmetry_std_dev                   0.350009        0.304383
# fractal_dimension_std_dev          0.648248        0.504069
# Worst_radius                       0.183277        0.437961
# Worst_texture                     -0.047665       -0.032081
# Worst_perimeter                    0.276994        0.514336
# Worst_area                         0.168275        0.421021
# Worst_smoothness                   0.452067        0.319247
# Worst_compactness                  0.764824        0.483300
# Worst_concavity                    0.743333        0.702673
# Worst_concave_points               0.761044        0.767571
# Worst_symmetry                     0.429953        0.212976
# Worst_fractal_dimension            0.611315        0.302868
# Tumor_Size                        -0.060199       -0.010244
#
#                            concave_points_mean     ...      Worst_texture  \
# Outcome                              -0.118224     ...           0.051134
# Time                                 -0.171841     ...          -0.171125
# radius_mean                           0.664010     ...          -0.039439
# texture_mean                          0.006687     ...           0.862050
# perimeter_mean                        0.712766     ...          -0.039728
# area_mean                             0.667530     ...          -0.032122
# smoothness_mean                       0.545734     ...          -0.106172
# compactness_mean                      0.716438     ...          -0.047665
# concavity_mean                        0.909990     ...          -0.032081
# concave_points_mean                   1.000000     ...          -0.094163
# symmetry_mean                         0.429968     ...          -0.137598
# fractal_dimension_mean                0.268210     ...          -0.039644
# radius_std_dev                        0.555034     ...          -0.143369
# texture_std_dev                       0.179486     ...           0.401277
# perimeter_std_dev                     0.580562     ...          -0.122254
# area_std_dev                          0.586508     ...          -0.106107
# smoothness_std_dev                    0.177402     ...          -0.082080
# compactness_std_dev                   0.376339     ...           0.019361
# concavity_std_dev                     0.463710     ...          -0.034301
# concave_points_std_dev                0.426638     ...          -0.197387
# symmetry_std_dev                      0.238520     ...          -0.164564
# fractal_dimension_std_dev             0.350050     ...          -0.065060
# Worst_radius                          0.630309     ...           0.018682
# Worst_texture                        -0.094163     ...           1.000000
# Worst_perimeter                       0.682749     ...           0.022827
# Worst_area                            0.604029     ...           0.031795
# Worst_smoothness                      0.174917     ...           0.108394
# Worst_compactness                     0.286599     ...           0.139112
# Worst_concavity                       0.471429     ...           0.126797
# Worst_concave_points                  0.764803     ...          -0.014506
# Worst_symmetry                        0.089804     ...          -0.013599
# Worst_fractal_dimension               0.101327     ...           0.101902
# Tumor_Size                            0.050040     ...          -0.011378
#
#                            Worst_perimeter  Worst_area  Worst_smoothness  \
# Outcome                          -0.231998   -0.235310         -0.038520
# Time                             -0.280596   -0.253930          0.212769
# radius_mean                       0.915053    0.891489         -0.372894
# texture_mean                      0.123674    0.117467         -0.113308
# perimeter_mean                    0.923659    0.889344         -0.331667
# area_mean                         0.925335    0.914166         -0.345111
# smoothness_mean                  -0.064664   -0.106691          0.745400
# compactness_mean                  0.276994    0.168275          0.452067
# concavity_mean                    0.514336    0.421021          0.319247
# concave_points_mean               0.682749    0.604029          0.174917
# symmetry_mean                     0.019708   -0.050522          0.355244
# fractal_dimension_mean           -0.265607   -0.318351          0.660332
# radius_std_dev                    0.660942    0.656442         -0.228740
# texture_std_dev                  -0.012545   -0.031464         -0.101748
# perimeter_std_dev                 0.663958    0.627129         -0.229088
# area_std_dev                      0.776267    0.793467         -0.241462
# smoothness_std_dev               -0.107891   -0.134124          0.251764
# compactness_std_dev               0.062830   -0.029747          0.212309
# concavity_std_dev                 0.128143    0.035591          0.146979
# concave_points_std_dev            0.153675    0.078840         -0.087175
# symmetry_std_dev                 -0.022235   -0.076271         -0.006900
# fractal_dimension_std_dev        -0.045958   -0.111979          0.282408
# Worst_radius                      0.985520    0.988038         -0.232365
# Worst_texture                     0.022827    0.031795          0.108394
# Worst_perimeter                   1.000000    0.974118         -0.198683
# Worst_area                        0.974118    1.000000         -0.209372
# Worst_smoothness                 -0.198683   -0.209372          1.000000
# Worst_compactness                 0.032482   -0.046204          0.544477
# Worst_concavity                   0.179592    0.096564          0.534364
# Worst_concave_points              0.497608    0.414882          0.463971
# Worst_symmetry                   -0.103293   -0.143860          0.397562
# Worst_fractal_dimension          -0.231634   -0.267430          0.658629
# Tumor_Size                        0.134169    0.141985         -0.128652
#
#                            Worst_compactness  Worst_concavity  \
# Outcome                             0.020067        -0.017621
# Time                                0.120516         0.009546
# radius_mean                        -0.150712         0.038952
# texture_mean                       -0.006467         0.013635
# perimeter_mean                     -0.092041         0.096790
# area_mean                          -0.141358         0.046641
# smoothness_mean                     0.447849         0.499438
# compactness_mean                    0.764824         0.743333
# concavity_mean                      0.483300         0.702673
# concave_points_mean                 0.286599         0.471429
# symmetry_mean                       0.488231         0.458280
# fractal_dimension_mean              0.683414         0.585507
# radius_std_dev                     -0.140472        -0.034290
# texture_std_dev                    -0.146005        -0.103871
# perimeter_std_dev                  -0.073668         0.019657
# area_std_dev                       -0.126673        -0.001336
# smoothness_std_dev                 -0.028113         0.045155
# compactness_std_dev                 0.664129         0.568806
# concavity_std_dev                   0.395843         0.585400
# concave_points_std_dev              0.046090         0.131590
# symmetry_std_dev                    0.175221         0.164151
# fractal_dimension_std_dev           0.518034         0.453047
# Worst_radius                       -0.047070         0.101924
# Worst_texture                       0.139112         0.126797
# Worst_perimeter                     0.032482         0.179592
# Worst_area                         -0.046204         0.096564
# Worst_smoothness                    0.544477         0.534364
# Worst_compactness                   1.000000         0.835064
# Worst_concavity                     0.835064         1.000000
# Worst_concave_points                0.633585         0.725540
# Worst_symmetry                      0.596932         0.488497
# Worst_fractal_dimension             0.847403         0.700962
# Tumor_Size                         -0.043905        -0.032928
#
#                            Worst_concave_points  Worst_symmetry  \
# Outcome                               -0.074345        0.074731
# Time                                  -0.026541        0.247678
# radius_mean                            0.357869       -0.232142
# texture_mean                          -0.069921       -0.186850
# perimeter_mean                         0.410000       -0.206949
# area_mean                              0.365026       -0.234294
# smoothness_mean                        0.531015        0.308964
# compactness_mean                       0.761044        0.429953
# concavity_mean                         0.767571        0.212976
# concave_points_mean                    0.764803        0.089804
# symmetry_mean                          0.501957        0.705076
# fractal_dimension_mean                 0.453304        0.493337
# radius_std_dev                         0.229593       -0.227902
# texture_std_dev                       -0.109804       -0.228037
# perimeter_std_dev                      0.275071       -0.215541
# area_std_dev                           0.275015       -0.232644
# smoothness_std_dev                     0.024474       -0.146274
# compactness_std_dev                    0.420393        0.284148
# concavity_std_dev                      0.393513        0.125586
# concave_points_std_dev                 0.294575       -0.118515
# symmetry_std_dev                       0.170082        0.540420
# fractal_dimension_std_dev              0.340270        0.203297
# Worst_radius                           0.434613       -0.133244
# Worst_texture                         -0.014506       -0.013599
# Worst_perimeter                        0.497608       -0.103293
# Worst_area                             0.414882       -0.143860
# Worst_smoothness                       0.463971        0.397562
# Worst_compactness                      0.633585        0.596932
# Worst_concavity                        0.725540        0.488497
# Worst_concave_points                   1.000000        0.400097
# Worst_symmetry                         0.400097        1.000000
# Worst_fractal_dimension                0.462019        0.565368
# Tumor_Size                            -0.047593       -0.166561
#
#                            Worst_fractal_dimension  Tumor_Size
# Outcome                                   0.055170   -0.177273
# Time                                      0.288715   -0.133355
# radius_mean                              -0.414340    0.172102
# texture_mean                             -0.085847    0.027073
# perimeter_mean                           -0.364022    0.166489
# area_mean                                -0.395026    0.174491
# smoothness_mean                           0.535751   -0.084376
# compactness_mean                          0.611315   -0.060199
# concavity_mean                            0.302868   -0.010244
# concave_points_mean                       0.101327    0.050040
# symmetry_mean                             0.458548   -0.151551
# fractal_dimension_mean                    0.838737   -0.128062
# radius_std_dev                           -0.265243    0.064281
# texture_std_dev                          -0.173675    0.003825
# perimeter_std_dev                        -0.231810    0.068565
# area_std_dev                             -0.276872    0.082925
# smoothness_std_dev                       -0.017428   -0.078691
# compactness_std_dev                       0.479000   -0.028029
# concavity_std_dev                         0.241911   -0.054702
# concave_points_std_dev                   -0.057835   -0.039704
# symmetry_std_dev                          0.085109   -0.098589
# fractal_dimension_std_dev                 0.581984   -0.045565
# Worst_radius                             -0.284795    0.145884
# Worst_texture                             0.101902   -0.011378
# Worst_perimeter                          -0.231634    0.134169
# Worst_area                               -0.267430    0.141985
# Worst_smoothness                          0.658629   -0.128652
# Worst_compactness                         0.847403   -0.043905
# Worst_concavity                           0.700962   -0.032928
# Worst_concave_points                      0.462019   -0.047593
# Worst_symmetry                            0.565368   -0.166561
# Worst_fractal_dimension                   1.000000   -0.072131
# Tumor_Size                               -0.072131    1.000000
#
# [33 rows x 33 columns]

# %%
plt.hist(df['Outcome'], color='r')
plt.title('Plot_Diagnosis (N=1 , R=0)')
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True)

# %%
# generate a scatter plot matrix with the "mean" columns
cols = ['Outcome',
        'Time',
        'radius_mean', 
        'texture_mean', 
        'perimeter_mean', 
        'area_mean', 
        'smoothness_mean', 
        'compactness_mean', 
        'concavity_mean',
        'concave_points_mean', 
        'symmetry_mean', 
        'fractal_dimension_mean']

sns.pairplot(data=df[cols], hue='Outcome', palette='rocket')

# %% [markdown]
# almost perfectly linear patterns between the radius, perimeter and area attributes are hinting at the presence of multicollinearity between these variables. (they are highly linearly related) Another set of variables that possibly imply multicollinearity are the concavity, concave_points and compactness.
#
# Multicollinearity is a problem as it undermines the significance of independent varibales and we fix it by removing the highly correlated predictors from the model Use Partial Least Squares Regression (PLS) or Principal Components Analysis, regression methods that cut the number of predictors to a smaller set of uncorrelated components.

# %%
# Generate and visualize the correlation matrix
corr = df.corr().round(2)

# Mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set figure size
f, ax = plt.subplots(figsize=(20, 20))

# Define custom colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

plt.tight_layout()

# %% [markdown]
# * we can verify the presence of multicollinearity between some of the variables. For instance, the radius_mean column has a correlation of 1 and 0.99 with perimeter_mean and area_mean columns, respectively. This is because the three columns essentially contain the same information, which is the physical size of the observation (the cell). Therefore we should only pick ONE of the three columns when we go into further analysis.
#
# * Another place where multicollienartiy is apparent is between the "mean" columns and the "worst" column. For instance, the radius_mean column has a correlation of 0.92 with the radius_worst column.

# %% [markdown]
# * also there is multicollinearity between the attributes compactness, concavity, and concave points. So we can choose just ONE out of these, I am going for Compactness.

# %%
# first, drop all "worst" columns
cols = ['Worst_radius', 
        'Worst_texture', 
        'Worst_perimeter', 
        'Worst_area', 
        'Worst_smoothness', 
        'Worst_compactness', 
        'Worst_concavity',
        'Worst_concave_points', 
        'Worst_symmetry', 
        'Worst_fractal_dimension']
df = df.drop(cols, axis=1)

# %%
# then, drop all columns related to the "perimeter" and "area" attributes
cols = ['perimeter_mean',
        'perimeter_std_dev', 
        'area_mean', 
        'area_std_dev']
df = df.drop(cols, axis=1)

# %%
# lastly, drop all columns related to the "concavity" and "concave points" attributes
cols = ['concavity_mean',
        'concavity_std_dev', 
        'concave_points_mean', 
        'concave_points_std_dev']
df = df.drop(cols, axis=1)

# %%
# verify remaining columns
df.columns
# Out:
# Index(['Outcome', 'Time', 'radius_mean', 'texture_mean', 'smoothness_mean',
#        'compactness_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_std_dev', 'texture_std_dev', 'smoothness_std_dev',
#        'compactness_std_dev', 'symmetry_std_dev', 'fractal_dimension_std_dev',
#        'Tumor_Size', 'Lymph_Node_Status'],
#       dtype='object')

# %%
# Draw the heatmap again, with the new correlation matrix
corr = df.corr().round(2)
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
plt.tight_layout()

# %%
# def str_column_to_float(df, column):
#     for row in df:
#         row[column] = float(row[column].strip())

# %%
df.head()
# Out:
#    Outcome   Time  radius_mean  texture_mean  smoothness_mean  \
# 0        1   31.0        18.02         27.60          0.09489
# 1        1   61.0        17.99         10.38          0.11840
# 2        1  116.0        21.37         17.44          0.08836
# 3        1  123.0        11.42         20.38          0.14250
# 4        0   27.0        20.29         14.34          0.10030
#
#    compactness_mean  symmetry_mean  fractal_dimension_mean  radius_std_dev  \
# 0            0.1036         0.1865                 0.06333          0.6249
# 1            0.2776         0.2419                 0.07871          1.0950
# 2            0.1189         0.2333                 0.06010          0.5854
# 3            0.2839         0.2597                 0.09744          0.4956
# 4            0.1328         0.1809                 0.05883          0.7572
#
#    texture_std_dev  smoothness_std_dev  compactness_std_dev  symmetry_std_dev  \
# 0           1.8900            0.004433              0.01421           0.01694
# 1           0.9053            0.006399              0.04904           0.03003
# 2           0.6105            0.006167              0.03449           0.03094
# 3           1.1560            0.009110              0.07458           0.05963
# 4           0.7813            0.011490              0.02461           0.01756
#
#    fractal_dimension_std_dev  Tumor_Size Lymph_Node_Status
# 0                   0.003495         5.0                 5
# 1                   0.006193         3.0                 2
# 2                   0.005039         2.5                 0
# 3                   0.009208         2.0                 0
# 4                   0.005115         3.5                 0

# %% [markdown]
# ## Building Model

# %%
X=df.drop(['Outcome'],axis=1)
y = df['Outcome']

# %%
X.describe()
# Out:
#              Time  radius_mean  texture_mean  smoothness_mean  \
# count  198.000000   198.000000     198.00000       198.000000
# mean    46.732323    17.412323      22.27601         0.102681
# std     34.462870     3.161676       4.29829         0.012522
# min      1.000000    10.950000      10.38000         0.074970
# 25%     14.000000    15.052500      19.41250         0.093900
# 50%     39.500000    17.290000      21.75000         0.101900
# 75%     72.750000    19.580000      24.65500         0.110975
# max    125.000000    27.220000      39.28000         0.144700
#
#        compactness_mean  symmetry_mean  fractal_dimension_mean  \
# count        198.000000     198.000000              198.000000
# mean           0.142648       0.192754                0.062706
# std            0.049898       0.027437                0.007240
# min            0.046050       0.130800                0.050250
# 25%            0.110200       0.174075                0.056718
# 50%            0.131750       0.189350                0.061715
# 75%            0.172200       0.209325                0.066715
# max            0.311400       0.304000                0.097440
#
#        radius_std_dev  texture_std_dev  smoothness_std_dev  \
# count      198.000000       198.000000          198.000000
# mean         0.603346         1.264450            0.006762
# std          0.310112         0.526467            0.002974
# min          0.193800         0.362100            0.002667
# 25%          0.388200         0.921300            0.005001
# 50%          0.533250         1.168500            0.006193
# 75%          0.750900         1.463250            0.007973
# max          1.819000         3.503000            0.031130
#
#        compactness_std_dev  symmetry_std_dev  fractal_dimension_std_dev  \
# count           198.000000        198.000000                 198.000000
# mean              0.031199          0.020555                   0.003987
# std               0.017613          0.009578                   0.001938
# min               0.007347          0.007882                   0.001087
# 25%               0.019803          0.014795                   0.002748
# 50%               0.027880          0.017905                   0.003719
# 75%               0.038335          0.022880                   0.004630
# max               0.135400          0.060410                   0.012560
#
#        Tumor_Size
# count  198.000000
# mean     2.847475
# std      1.937964
# min      0.400000
# 25%      1.500000
# 50%      2.500000
# 75%      3.500000
# max     10.000000

# %%
y.describe()
# Out:
# count    198.000000
# mean       0.762626
# std        0.426552
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: Outcome, dtype: float64

# %%
from sklearn import decomposition,linear_model,datasets
import numpy as np
import time
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=40)

# %%
X_train.head(158)
# Out:
#       Time  radius_mean  texture_mean  smoothness_mean  compactness_mean  \
#
# 171            0.005769             0.024230           0.01898
# 23             0.005627             0.030330           0.01925
# 132            0.010520             0.024310           0.02120
# 37             0.006294             0.039940           0.02428
# 151            0.005467             0.020750           0.01029
# 28             0.005776             0.024990           0.02789
# 85             0.004044             0.015970           0.01522
# 93             0.006804             0.031690           0.01897
# 174            0.007800             0.047680           0.02759
# 75             0.004631             0.025370           0.01575
# 18             0.006048             0.018820           0.01468
# 105            0.006356             0.047650           0.01936
# 121            0.007964             0.047320           0.02736
# 130            0.009329             0.065590           0.05543
# 33             0.008064             0.017640           0.01357
# 46             0.004717             0.020650           0.01220
# 168            0.004625             0.048440           0.02137
# 169            0.006399             0.043100           0.02057
# 11             0.005771             0.040610           0.02008
# 166            0.004989             0.032120           0.01879
# 81             0.009098             0.038450           0.01878
# 111            0.002826             0.009105           0.01013
# 67             0.009037             0.049540           0.01778
# 147            0.005314             0.017910           0.01223
#
#      fractal_dimension_std_dev  Tumor_Size Lymph_Node_Status
# 96                    0.005617         3.0                27
# 5                     0.005114         2.5                 0
# 116                   0.003446         1.5                 0
# 35                    0.003317         2.6                 1
# 180                   0.002027         0.8                 0
# 160                   0.006995         1.0                 0
# 54                    0.003884         1.5                 4
# 134                   0.004286         2.5                 2
# 90                    0.012560         1.5                 1
# 190                   0.003700         4.0                 0
# 139                   0.006240         4.0                13
# 142                   0.001750         4.0                13
# 177                   0.002098         2.7                 4
# 26                    0.003896         3.5                 0
# 89                    0.003708         3.2                 0
# 140                   0.004028         3.3                16
# 171                   0.002498         1.0                 0
# 23                    0.003742         4.0                 0
# 132                   0.004867         2.6                 0
# 37                    0.003535         1.8                 0
# 151                   0.002205         2.8                 0
# 28                    0.002665         1.5                 ?
# 85                    0.001976         1.5                 ?
# 93                    0.004045         2.6                 0
# 174                   0.004116         2.4                 2
# 75                    0.002747         4.0                 4
# 18                    0.002801         3.0                 0
# 105                   0.005252         6.0                15
# 121                   0.005928         5.0                11
# 130                   0.007330         1.8                 0
# 33                    0.003040         2.7                 0
# 46                    0.003130         3.0                 2
# 168                   0.006142         2.5                 0
# 169                   0.006213         1.5                 0
# 11                    0.004144         1.4                 0
# 166                   0.004760         1.0                 1
# 81                    0.005672         1.2                 4
# 111                   0.001345         2.0                 0
# 67                    0.004968         9.0                 7
# 147                   0.002846         3.5                 4

# %% [markdown]
# ## Feature Scaling

# %%
ss=StandardScaler()

# %%
X_test=ss.fit_transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-a10d5d8d5641> in <module>
# ----> 1 X_test=ss.fit_transform(X_test)
#
# C:\Users\Anaconda\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     460         if y is None:
#     461             # fit method of arity 1 (unsupervised transformation)
# --> 462             return self.fit(X, **fit_params).transform(X)
#     463         else:
#     464             # fit method of arity 2 (supervised transformation)
#
# C:\Users\Anaconda\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     623         # Reset internal state before fitting
#     624         self._reset()
# --> 625         return self.partial_fit(X, y)
#     626
#     627     def partial_fit(self, X, y=None):
#
# C:\Users\Anaconda\lib\site-packages\sklearn\preprocessing\data.py in partial_fit(self, X, y)
#     647         X = check_array(X, accept_sparse=('csr', 'csc'), copy=self.copy,
#     648                         warn_on_dtype=True, estimator=self, dtype=FLOAT_DTYPES,
# --> 649                         force_all_finite='allow-nan')
#     650
#     651         # Even in the case of `with_mean=False`, we update the mean anyway
#
# C:\Users\Anaconda\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# C:\Users\Anaconda\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     499
#     500     """
# --> 501     return array(a, dtype, copy=False, order=order)
#     502
#     503
#
# ValueError: could not convert string to float: '?'
