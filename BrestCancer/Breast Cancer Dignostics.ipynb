# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('BreastCancer_Prognostic_v11.csv')

# %%
df.head()
# Out:
#          ID Outcome   Time  radius_mean  texture_mean  perimeter_mean  \
# 0  119513.0       N   31.0        18.02         27.60          117.50
# 1    8423.0       N   61.0        17.99         10.38          122.80
# 2  842517.0       N  116.0        21.37         17.44          137.50
# 3  843483.0       N  123.0        11.42         20.38           77.58
# 4  843584.0       R   27.0        20.29         14.34          135.10
#
#    area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0     1013.0          0.09489            0.1036          0.1086
# 1     1001.0          0.11840            0.2776          0.3001
# 2     1373.0          0.08836            0.1189          0.1255
# 3      386.1          0.14250            0.2839          0.2414
# 4     1297.0          0.10030            0.1328          0.1980
#
#          ...          Worst_perimeter  Worst_area  Worst_smoothness  \
# 0        ...                   139.70      1436.0            0.1195
# ...

# %%
df.tail()
# Out:
#      ID Outcome  Time  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 994 NaN     NaN   NaN          NaN           NaN             NaN        NaN
# 995 NaN     NaN   NaN          NaN           NaN             NaN        NaN
# 996 NaN     NaN   NaN          NaN           NaN             NaN        NaN
# 997 NaN     NaN   NaN          NaN           NaN             NaN        NaN
# 998 NaN     NaN   NaN          NaN           NaN             NaN        NaN
#
#      smoothness_mean  compactness_mean  concavity_mean        ...          \
# 994              NaN               NaN             NaN        ...
# 995              NaN               NaN             NaN        ...
# 996              NaN               NaN             NaN        ...
# 997              NaN               NaN             NaN        ...
# 998              NaN               NaN             NaN        ...
#
#      Worst_perimeter  Worst_area  Worst_smoothness  Worst_compactness  \
# ...

# %%
df.shape
# Out:
# (999, 35)

# %%
df.describe().T
# Out:
#                            count          mean           std          min  \
# ID                         198.0  1.990469e+06  2.889025e+06  8423.000000
# Time                       198.0  4.673232e+01  3.446287e+01     1.000000
# radius_mean                198.0  1.741232e+01  3.161676e+00    10.950000
# texture_mean               198.0  2.227601e+01  4.298290e+00    10.380000
# perimeter_mean             198.0  1.148566e+02  2.138340e+01    71.900000
# area_mean                  198.0  9.700409e+02  3.521492e+02   361.600000
# smoothness_mean            198.0  1.026814e-01  1.252243e-02     0.074970
# compactness_mean           198.0  1.426478e-01  4.989760e-02     0.046050
# concavity_mean             198.0  1.562428e-01  7.057226e-02     0.023980
# concave_points_mean        198.0  8.677561e-02  3.387663e-02     0.020310
# symmetry_mean              198.0  1.927540e-01  2.743689e-02     0.130800
# fractal_dimension_mean     198.0  6.270551e-02  7.239530e-03     0.050250
# ...

# %%
df.Outcome.unique()
# Out:
# array(['N', 'R', nan], dtype=object)

# %%
df['Outcome'].value_counts()
# Out:
# N    151
# R     47
# Name: Outcome, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(df['Outcome'], palette='husl')

# %%
#checking the number of empty rows in th csv file
print (df.isnull().sum())
# Out:
# ID                           801
# Outcome                      801
# Time                         801
# radius_mean                  801
# texture_mean                 801
# perimeter_mean               801
# area_mean                    801
# smoothness_mean              801
# compactness_mean             801
# concavity_mean               801
# concave_points_mean          801
# symmetry_mean                801
# fractal_dimension_mean       801
# radius_std_dev               801
# texture_std_dev              801
# perimeter_std_dev            801
# area_std_dev                 801
# smoothness_std_dev           801
# compactness_std_dev          801
# concavity_std_dev            801
# concave_points_std_dev       801
# symmetry_std_dev             801
# fractal_dimension_std_dev    801
# Worst_radius                 801
# Worst_texture                801
# Worst_perimeter              801
# Worst_area                   801
# Worst_smoothness             801
# ...

# %%
#Droping the empty rows
modifyedBC = df.dropna()

# %%
# #Saving it to the csv file 
# modifyedBC.to_csv('BreastCancer_Prognostic_v12.csv',index=False)

# %%
df.describe()
# Out:
#                  ID        Time  radius_mean  texture_mean  perimeter_mean  \
# count  1.980000e+02  198.000000   198.000000     198.00000      198.000000
# mean   1.990469e+06   46.732323    17.412323      22.27601      114.856566
# std    2.889025e+06   34.462870     3.161676       4.29829       21.383402
# min    8.423000e+03    1.000000    10.950000      10.38000       71.900000
# 25%    8.557452e+05   14.000000    15.052500      19.41250       98.160000
# 50%    8.863390e+05   39.500000    17.290000      21.75000      113.700000
# 75%    9.279958e+05   72.750000    19.580000      24.65500      129.650000
# max    9.411300e+06  125.000000    27.220000      39.28000      182.100000
#
#          area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# count   198.000000       198.000000        198.000000      198.000000
# mean    970.040909         0.102681          0.142648        0.156243
# std     352.149215         0.012522          0.049898        0.070572
# ...

# %%
df1 = pd.read_csv('BreastCancer_Prognostic_v12.csv')

# %%
df1.isnull().sum()
# Out:
# ID                           0
# Outcome                      0
# Time                         0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave_points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_std_dev               0
# texture_std_dev              0
# perimeter_std_dev            0
# area_std_dev                 0
# smoothness_std_dev           0
# compactness_std_dev          0
# concavity_std_dev            0
# concave_points_std_dev       0
# symmetry_std_dev             0
# fractal_dimension_std_dev    0
# Worst_radius                 0
# Worst_texture                0
# Worst_perimeter              0
# Worst_area                   0
# Worst_smoothness             0
# Worst_compactness            0
# Worst_concavity              0
# ...
