# %% [markdown]
# Neural Network Architecture

# %% [markdown]
# * Q> How many parameters do we require for our neural network ?
#     OR
#     How can I calculate the number of parameters in an artificial neural network in order to calculate its AIC?

# %% [markdown]
# * Every connection that is learned in a feedforward network is a parameter. Here is an image of a generic network from Wikipedia:
#
# ![image.png](attachment:image.png)
#
# This network is fully connected, although networks don't have to be (e.g., designing a network with receptive fields improves edge detection in images). With a fully connected ANN, the number of connections is simply the sum of the product of the numbers of nodes in connected layers. In the image above, that is (3×4)+(4×2)=20. That image does not show any bias nodes, but many ANNs do have them; if so, include the bias node in the total for that layer. More generally (e.g., if your ANN isn't fully connected), you can simply count the connections.

# %% [markdown]
# * For a MLP fully connected network you can use the following (Python) code:

# %%
def total_param(l=[]):
    s=0
    for i in range(len(l)-1):
        s=s+l[i]*l[i+1]+l[i+1]
    return s

# %% [markdown]
# input:  435
# hidden: 166
# hidden: 103
# hidden:  64
# output:  15

# %%
total_param([435,166,103,64,15])
# Out:
# 97208

# %% [markdown]
# input: 784, hidden1: 256, hidden2: 256, output: 10

# %%
print(total_param([784,256,256,10]))
# Out:
# 269322
