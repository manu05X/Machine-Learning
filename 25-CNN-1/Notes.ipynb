# %% [markdown]
# ##### CNN Image Processing
#
# Q>
#     A Convolution Neural Network processes images -
#
# * Options
#
#         one pixel at a time
#
#         a group of pixels at a time
#
#         an entire image at a time
#
# Correct Answer: 2

# %% [markdown]
# ##### CNN Image Processing
#
# Q>
#    What is the problem with treating each pixel individually for image classification
#
#
# * Options
#
#         There are a lot of features to work with
#
#         Some pixels combined together generate patterns which are not recognized if treated separately
#
#         Training and testing time becomes very large for flattened form of image
#
# Correct Answer: 2

# %% [markdown]
# ##### CNN use
#
# Q>
#    Convolutional neural networks are widely used for
# Options
#
#
# * Options
#
#         image and video recognition
#
#         recommender systems
#
#         natural language processing
#
# Correct Answer: 1,2,3

# %% [markdown]
# ##### CNN Filter
#
# Q>
#    k*k filter in each convolutional unit is
#
# * Options
#
#         passed over entire image
#
#         fixed at a particular position on image
#
# Correct Answer: 1

# %% [markdown]
# ##### CNN Filter
#
# Q>
#    Each k*k filter in a convolutional unit is used to
#
#
# * Options
#
#         identify a pattern anywhere in image
#
#         identify a pattern at a fixed position in an image
#
#         identify all different patterns anywhere in image
#
#         identify all different patterns at a fixed position in an image
#
# Correct Answer: 1

# %% [markdown]
# ##### Output of Convolution Layer
#
# Q>
#    Consider a K x K filter applied on a K x K part of the image. Let pij be the pixels in the image part and wij be the weights in the filter. Then the final value given as output by the unit applying the filter will be:
#
# * Options
#
#         ΣjΣipijwij (0<=i<=k, 0<=j<=k)
#
#         ΣjΣipijwij (0<=i<=k-1, 0<=j<=k-1)
#
#         ΣjΣipijwij (1<=i<=k, 1<=j<=k)
#
#         ΣjΣipijwij (1<=i<=k-1, 1<=j<=k-1)
#
# Correct Answer: 2

# %% [markdown]
# ##### Stride Value
#
# Q>
#    Why shouldn’t we have stride value greater than K, the filter dimension?
#
# * Options
#
#         It will need more training.
#
#         It will consume more time.
#
#        It will leave gaps in between two parts of the image to be process, and we might thus lose valuable information.
#
# Correct Answer: 3

# %% [markdown]
# ##### Stride Value
#
# Q>
#    Increasing the size of stride will -
#
# * Options
#
#         Reduce output size
#
#         Increase output size
#
#
# Correct Answer: 1

# %% [markdown]
# ##### Stride and padding
#
# Q>
#    Find output dimensions of an 800 x 600 image passed through an convolutional unit with k x k = 3*3 and stride = 2 (consider no padding )
#
# * Options
#
#         400*300
#
#         300*400
#
#         399*299
#
#         299*399
#
# Correct Answer: 3

# %% [markdown]
# ##### Channels
#
# Q>
#    Channels for coloured images refers to
#
# * Options
#
#         3 dimensions of image
#
#         RGB values for colour of image
#
# Correct Answer: 2

# %% [markdown]
# ##### Channels
#
# Q>
#    What would be the channel value for 2nd convolutional layer
#
# * Options
#
#         RGB values for colour in transformed image
#
#         dimensions of image after 1st pooling later
#
#         number of Convolutional units in 1st layer
#
# Correct Answer: 3

# %% [markdown]
# ##### Stride and padding
#
# Q>
#    For an image with 28*28 pixels and 32 convolutional units , output is of shape(consider same padding):
#
# * Options
#
#         32*32
#
#         28*28*32
#
#         32*28*32*28
#
#         32*32*28
#
# Correct Answer: 2
#
# Solution Description
# For same padding output image is of same shape as input so, it would be 28 \* 28 . Since there are 32 convolution units , output would have 32 images of 28 * 28 thus output has dimension 28\*28\*32

# %% [markdown]
# ##### Pooling
#
# Q>
#    What is the purpose of pooling
#
# * Options
#
#         to reduce the size of image
#
#         to increase a layer as increasing layers in neutral networks
#
#         increases accuracy
#
#         to increase resolution of image
#
# Correct Answer: 1

# %% [markdown]
# ##### Pooling Layer
#
# Q>
#    Pooling layers are applied:
#
# * Options
#
#         After convolution layer
#
#         Instead of convolution layer
#
#         As the first layer of network
#
#
# Correct Answer: 1

# %% [markdown]
# ##### Pooling Layer Output
#
# Q>
#    If our image size is 18x18 and pool size 3x3, what will be the dimensions of the output from the pooling layer?
#
# * Options
#
#         18x18
#
#         6x6
#
#         3x3
#
#
# Correct Answer: 2

# %% [markdown]
# ##### Pooling
#
# Q>
#    Find the output of max pooling with stride = 2 and filter dimension k=2 for following output matrix :
#
# ![image.png](attachment:image.png)
#
# Note: Fill answer in space separated form
#
# * Answer : 6834

# %% [markdown]
# ##### Data flow
#
# What would be the output of a network with 32 units in 1st convolutional layer followed by a pooling layer then followed by another convolutional layer with 64 units followed by another pooling layer. Take stride = 2 and k=2 for both convolution layers and take the pool size = 2 in both pooling layers , input image dimensions are 28*28*1
# (fill answer in m*n*k form)
#
#
# * Answer :1*!*64
#
#
# ohk so we have a image of dims 28*28*1
#
#
# when an image of dimension x*y*z passes through a conv. layer of stride = 1 and k CNN units its dims changes to x*y*k
#
#
# that means width and height remain same and depth changes to no. of CNN units in the CNN layer
#
#
# but since stride = 2 for conv layer the depth and height will be halve too
#
#
# thus when 28*28*1 dims image passes through the fiirst conv. layer the depth becomes 32 and width and height are halved
#
#
# making it 14*14*32
#
#
# and when it passes through 1st pooling layers depth remains same and width and height are halved
#
#
# making it 7*7*32
#
#
# now when 7*7*32 dims image passes through the secomd conv. layer the depth becomes 64 and width and height are halved
#
#
# making it 3*3*64
#
#
# and when it passes through 2nd pooling layers depth remains same and width and height are halved
#
#
# making it 1*1*64
#
#
# hence the answer 1*1*64

# %% [markdown]
# ##### Completing network
#
# Q>
#    What would be the output of Convolutional layer :
#
# * Options
#
#         Classes to which image belongs to
#
#         image in higher resolution
#
#         Transformed image in lower resolution
#
#
# Correct Answer: 3

# %% [markdown]
# ##### Output Layer CNN
#
# Q>
#    The number of units in the output layer of a CNN is:
#
# * Options
#
#         The number of convolution layers in between
#
#         The number of units in the previous layer
#
#         The number of outputs/class labels for the dataset
#
# Correct Answer: 3
