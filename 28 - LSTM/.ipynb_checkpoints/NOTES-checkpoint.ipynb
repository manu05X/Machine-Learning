# %% [markdown]
# #### Vanishing/exploding gradient problem
# Q>
# Exploding/vanishing gradients are more problematic in the case of:
#
# * Options
#
#         CNNs
#
#         ANNs
#
#         RNNs
#
# Correct Answer: 3

# %% [markdown]
# ### Effect of Vanishing Gradient
# Q>
# Effect of vanishing gradient problem with respect to initial input is:
#
# * Options
#
#         Variations in initial input shows negligible effect on final output
#
#         Variations in initial input shows huge effect on final output
#
#        Weights for initial inputs change negligibly
#
#        Weights for initial inputs change exponentially
#
# Correct Answer1,3

# %% [markdown]
# ### Effect of Exploding Gradient
# Q>
# Effect of exploding gradient problem with respect to initial input is :
# * Options
#
#         Variations in initial input shows negligible effect on final output
#
#         Variations in initial input shows huge effect on final output
#
#         Weights for initial inputs change exponentially
#
#         Weights for initial inputs change negligibly
#
# Correct Answe:r2,3

# %% [markdown]
# ### Vanishing Gradient in RNN
# Q>
# Vanishing gradient problem is faced when output is generated by passing input to a large number of hidden layers , why does this problem occurs in RNN where a single layer of RNN units is used:
#
# * Options
#
#         Output of RNN layer is decided by back propagating on all its initial values resulting in multiple weight updates.
#
#         More number of RNN units creates this problem
#
#         The time taken to train RNN is very large so weights decrease along time
#
# Correct Answer:1

# %% [markdown]
# ### Purpose of GRU
# Q>
# The purpose of using GRU is:
# * Options
#
#         Solve vanishing gradient problem in RNN
#
#         Enable memory unit to decide whether to update its memory output for current input or not
#
#         Get a way to pass a_i-1 as a_i without making any changes based on current input
#
#         None of the above
#
# Correct Answer: 1,2,3

# %% [markdown]
# ### Training GRU
# Q>
# GRU units are faster to train as:
# * Options
#
#         They tend work better on smaller datasets
#
#         They involve less weights to train
#
#         The do not use previous values at all
#
#         None of the above
#
# Correct Answer: 1,2

# %% [markdown]
# ### Gates in GRU
# Q>
# The two gates in a GRU are:
# * Options
#
#         set and reset
#
#         reset and forget
#
#         set and forget
#
# Correct Answer:2

# %% [markdown]
# ### Purpose of Gates
# Q>
# Work to determine how much of the past information is needed to be passed along future is done by:
#
# * Options
#
#         Manually done at each stage
#
#         Update gate
#
#         Reset gate
#
# Correct Answer:2

# %% [markdown]
# ### Purpose of Gates
# Q>
# Work to determine how much of the past information is to be forgotten is done by :
#
# * Options
#
#         Manually done at each stage
#
#         Update gate
#
#         Reset gate
#
# Correct Answer:3

# %% [markdown]
# ### Minimal Gated Unit
# Q>
# Minimal gated unit uses equal weights and biases for reset and update gate .
# * Options
#
#         True
#
#         False
#
# Correct Answer:1

# %% [markdown]
# ### Activation Of memory cell
# Q>
# The memory cell has some activation applied on to give C_t
#
# * Options
#
#         True
#
#         False
#
# Correct Answer: 2

# %% [markdown]
# ### Activation on Memory Cell
# Q>
# The purpose of not applying activation on memory cell is to :
#
# * Options
#
#         Make model easy to understand
#
#         Have less weights than GRU
#
#         Prevent the vanishing gradient as without activation weights are not changed drastically when back propagated through time
#
# Correct Answer: 3

# %% [markdown]
# ### Activation in input gate
# Q>
# The activation function usually used in the input gate of a LSTM is:
# * Options
#
#         RELU (Rectified Linear Unit)
#
#         Tanh (Hyperbolic Tan)
#
#         Sigmoid
#
# Correct Answer:3

# %% [markdown]
# ### Purpose of output gate
# Q>
# What is the purpose of output gate :
#
# * Options
#
#         To decide the value of memory cell
#
#         To decide output based on current input a_t-1 only
#
#         To decide extent to which C_t affect activation output
#
# Correct Answer:3

# %% [markdown]
# ### Purpose of Input and Output gates
# Q>
# In the equation to calculate C_t what is the function of input(i) and forget(f) gates respectively :
#
# * Options
#
#         Input gate decides the contribution of new candidate for memory in C_t and forget gate decides contribution of previous memory cell value in C_t
#
#         Forget gate decides the contribution of new candidate for memory in C_t and input gate decides contribution of previous memory cell value in C_t
#
#         Input gate decides the activation on input and forget gate decides activation on output
#
#         None of the above
#
# Correct Answer: 1
